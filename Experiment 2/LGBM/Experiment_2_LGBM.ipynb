# %%
# Full updated script: LGBM with only Technology-labeled FinBERT sentiment

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from tqdm import tqdm

# === Load stock data ===
df = pd.read_csv("cleaned_stock_data_without_arm.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(['Company', 'Date'])

# Fix commas and convert price
df['Price Close'] = df['Price Close'].astype(str).str.replace(",", ".", regex=False)
df['Price Close'] = pd.to_numeric(df['Price Close'], errors='coerce')

# Load and prepare technology-only sentiment
sentiment_df = pd.read_csv("finbert_sentiment_final.csv")
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])
sentiment_df = sentiment_df[sentiment_df['Predicted_Label'] == 'Technology']

map_df = pd.read_excel("matched company names .xlsx")
map_df.columns = ['company', 'Company']
sentiment_df = sentiment_df.merge(map_df, on='company', how='inner')
sentiment_df = sentiment_df[sentiment_df['Company'] != 'ARM.O']
sentiment_df = sentiment_df[['Company', 'date', 'finbert_sentiment_label']]
sentiment_df['date'] = sentiment_df['date'].dt.normalize()

# Aggregate and map sentiment
avg_sentiment = sentiment_df.groupby(['Company', 'date'])['finbert_sentiment_label'].mean().reset_index()
avg_sentiment = avg_sentiment.rename(columns={'date': 'Date', 'finbert_sentiment_label': 'Sentiment'})

# Merge into df
df = pd.merge(df, avg_sentiment, on=['Company', 'Date'], how='left')

# Apply conditional decay to sentiment
def apply_conditional_decay(series, decay=0.9):
    output = []
    last_val = None
    for val in series:
        if pd.notna(val):
            if val == 0:
                last_val = None
                output.append(np.nan)
            else:
                last_val = val
                output.append(val)
        else:
            if last_val is not None:
                last_val *= decay
                output.append(last_val)
            else:
                output.append(np.nan)
    return output

df = df.sort_values(['Company', 'Date'])
df['Sentiment'] = df.groupby('Company')['Sentiment'].transform(lambda x: apply_conditional_decay(x))

# Time features
df['DayOfWeek'] = df['Date'].dt.dayofweek
df['Month'] = df['Date'].dt.month
df['Day_Sin'] = np.sin(2 * np.pi * df['DayOfWeek'] / 7)
df['Day_Cos'] = np.cos(2 * np.pi * df['DayOfWeek'] / 7)
df['Month_Sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_Cos'] = np.cos(2 * np.pi * df['Month'] / 12)

# Lagged return, price, volume
df['Return'] = df.groupby('Company')['Price Close'].pct_change()
df['Lag1_Return'] = df.groupby('Company')['Return'].shift(1)
df['Lag2_Return'] = df.groupby('Company')['Return'].shift(2)
df['Lag3_Return'] = df.groupby('Company')['Return'].shift(3)
df['Lagged_Volume'] = df.groupby('Company')['Volume'].shift(1)

# Rolling stats
df['RollingStd_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).std())
df['RollingMean_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).mean())

# Lagged sentiment
df['Lagged_Sentiment'] = df.groupby('Company')['Sentiment'].shift(1)

# Drop rows with missing target only (predicting return)
df = df.dropna(subset=['Return'])

# Load best params and index
param_df = pd.read_csv("best_params_all_companies.csv")
index_df = pd.read_csv("equal_weighted_index_without_arm.csv")
index_df['Date'] = pd.to_datetime(index_df['Date'])

# Split
unique_dates = df['Date'].sort_values().unique()
split_idx = int(len(unique_dates) * 0.8)
train_dates = unique_dates[:split_idx]
test_dates = unique_dates[split_idx:]

last_train_date = train_dates[-1]
start_value = index_df.loc[index_df['Date'] == last_train_date, 'Index_Level'].values[0] \
    if last_train_date in index_df['Date'].values else index_df[index_df['Date'] < last_train_date]['Index_Level'].iloc[-1]

# === Training ===
all_preds = []
plotted = 0

for company in tqdm(df['Company'].unique(), desc="LGBM Forecasting"):
    company_data = df[df['Company'] == company].copy()
    params_row = param_df[param_df['Company'] == company]

    if len(params_row) == 0:
        continue

    params = {
        'num_leaves': int(params_row['num_leaves'].values[0]),
        'learning_rate': float(params_row['learning_rate'].values[0]),
        'feature_fraction': float(params_row['feature_fraction'].values[0]),
        'min_data_in_leaf': int(params_row['min_data_in_leaf'].values[0]),
        'lambda_l2': float(params_row['lambda_l2'].values[0]),
        'lambda_l1': 0.5,
        'max_depth': 6,
        'verbosity': -1
    }

    train = company_data[company_data['Date'].isin(train_dates)]
    test = company_data[company_data['Date'].isin(test_dates)]
    if len(train) < 50 or len(test) < 1:
        continue

    features = [
        'Lag1_Return', 'Lag2_Return', 'Lag3_Return', 'Lagged_Volume',
        'RollingStd_5', 'RollingMean_5', 'Lagged_Sentiment',
        'Day_Sin', 'Day_Cos', 'Month_Sin', 'Month_Cos'
    ]

    X_all = company_data[features].values
    y_all = company_data['Return'].values.reshape(-1, 1)

    split_idx = len(train)
    X_train = X_all[:split_idx]
    y_train = y_all[:split_idx]
    X_test = X_all[split_idx:]
    y_test = y_all[split_idx:]

    f_scaler = StandardScaler()
    X_train_scaled = f_scaler.fit_transform(X_train)
    X_test_scaled = f_scaler.transform(X_test)

    model = lgb.LGBMRegressor(n_estimators=500, **params)
    tscv = TimeSeriesSplit(n_splits=5)
    for train_idx, val_idx in tscv.split(X_train_scaled):
        model.fit(
            X_train_scaled[train_idx], y_train[train_idx].ravel(),
            eval_set=[(X_train_scaled[val_idx], y_train[val_idx].ravel())],
            callbacks=[early_stopping(50), log_evaluation(0)]
        )

    preds = model.predict(X_test_scaled)
    test_result = test.iloc[-len(preds):].copy()
    test_result['Predicted_Return'] = preds
    test_result['Predicted_Return'] = test_result['Predicted_Return'].clip(lower=-0.1, upper=0.1)

    test_result['Predicted_Price'] = test_result['Price Close'].shift(1) * (1 + test_result['Predicted_Return'])
    test_result['Predicted_Price'] = test_result['Predicted_Price'].cumprod() / test_result['Predicted_Price'].iloc[0] * test_result['Price Close'].iloc[0]

    if plotted < 5:
        plt.figure(figsize=(10, 4))
        plt.plot(test_result['Date'], test_result['Price Close'], label='Actual', color='blue')
        plt.plot(test_result['Date'], test_result['Predicted_Price'], label='Predicted', color='orange')
        plt.title(f"{company} - Predicted vs Actual Price")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.legend()
        plt.tight_layout()
        plt.savefig(f"pred_vs_actual_{company}_tech_only.png", dpi=200)
        plt.close()
        plotted += 1

    test_result['Company'] = company
    all_preds.append(test_result[['Date', 'Company', 'Predicted_Return']])

# === Aggregate index ===
combined = pd.concat(all_preds)
index_returns = combined.groupby('Date')['Predicted_Return'].mean().reset_index()
index_returns.rename(columns={'Predicted_Return': 'Index_Predicted_Return'}, inplace=True)
index_returns['Predicted_Index_Level'] = (1 + index_returns['Index_Predicted_Return']).cumprod() * start_value

index_df['Date'] = pd.to_datetime(index_df['Date'])
index_returns['Date'] = pd.to_datetime(index_returns['Date'])

final = pd.merge(index_df[['Date', 'Index_Level']], index_returns, on='Date', how='inner')
final.to_csv("lgbm_index_tech_sentiment_only.csv", index=False)

plt.figure(figsize=(14, 6))
plt.plot(final['Date'], final['Index_Level'], label='Actual Index Price', color='blue')
plt.plot(final['Date'], final['Predicted_Index_Level'], label='Predicted Index Price', color='orange')
plt.xlabel("Date")
plt.ylabel("Index Price")
plt.legend()
plt.tight_layout()
plt.savefig("lgbm_index_tech_sentiment_forecast.png", dpi=300)
plt.show()

rmse = np.sqrt(mean_squared_error(final['Index_Level'], final['Predicted_Index_Level']))
print(f"LGBM Index Level RMSE (Tech Sentiment Only): {rmse:.2f}")
# Out:
# LGBM Forecasting:   0%|          | 0/44 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [343]	valid_0's l2: 0.000231288
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [474]	valid_0's l2: 0.000431824
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000426199
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [322]	valid_0's l2: 0.000109296
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.67225e-05
# LGBM Forecasting:   2%|▏         | 1/44 [00:01<00:54,  1.27s/it]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00047763
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00070493
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [207]	valid_0's l2: 0.000613577
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000342955
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000216431
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   5%|▍         | 2/44 [00:02<00:47,  1.12s/it]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00023705
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000499117
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000433869
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000215415
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000151252
# LGBM Forecasting:   7%|▋         | 3/44 [00:03<00:40,  1.00it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000603801
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000925462
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000616345
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000367197
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [181]	valid_0's l2: 0.000200883
# LGBM Forecasting:   9%|▉         | 4/44 [00:03<00:33,  1.21it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00061012
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000889343
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000690199
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000307005
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000274508
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  11%|█▏        | 5/44 [00:04<00:32,  1.21it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000968449
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00141868
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l2: 0.000982033
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000573557
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  14%|█▎        | 6/44 [00:04<00:24,  1.54it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000483037
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000321374
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000683946
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [183]	valid_0's l2: 0.000455065
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  16%|█▌        | 7/44 [00:05<00:19,  1.88it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000219674
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [391]	valid_0's l2: 0.000401477
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00178609
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00307543
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  18%|█▊        | 8/44 [00:05<00:16,  2.19it/s]
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00172972
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [171]	valid_0's l2: 0.00106636
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [199]	valid_0's l2: 0.000895257
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00050162
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000971433
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [371]	valid_0's l2: 0.000729912
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000244613
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  20%|██        | 9/44 [00:05<00:13,  2.55it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [194]	valid_0's l2: 0.000243622
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00030115
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [278]	valid_0's l2: 0.000492414
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [293]	valid_0's l2: 0.000414746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [240]	valid_0's l2: 0.000374923
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  23%|██▎       | 10/44 [00:05<00:11,  2.90it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [323]	valid_0's l2: 0.000324575
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000445451
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000674413
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l2: 0.000404069
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000217984
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  25%|██▌       | 11/44 [00:06<00:10,  3.01it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000207979
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000238897
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [379]	valid_0's l2: 0.000401099
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000273407
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  27%|██▋       | 12/44 [00:06<00:09,  3.36it/s]
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [468]	valid_0's l2: 0.000254528
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid_0's l2: 8.00383e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000875304
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00185741
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000902806
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000518615
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  30%|██▉       | 13/44 [00:06<00:10,  2.95it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid_0's l2: 0.000393342
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000178441
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000448209
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000447048
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000202485
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  32%|███▏      | 14/44 [00:07<00:10,  2.95it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  34%|███▍      | 15/44 [00:07<00:08,  3.44it/s]
# Early stopping, best iteration is:
# [252]	valid_0's l2: 9.82708e-05
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00133768
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.00338811
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [216]	valid_0's l2: 0.001245
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	valid_0's l2: 0.000366823
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [131]	valid_0's l2: 0.000536035
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid_0's l2: 0.00110623
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [229]	valid_0's l2: 0.00245428
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [349]	valid_0's l2: 0.00118651
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l2: 0.000727279
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  36%|███▋      | 16/44 [00:07<00:07,  3.53it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [92]	valid_0's l2: 0.000734987
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000751
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00130682
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [466]	valid_0's l2: 0.000661376
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid_0's l2: 0.000617586
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  39%|███▊      | 17/44 [00:08<00:10,  2.62it/s]
# Early stopping, best iteration is:
# [413]	valid_0's l2: 0.000305215
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00149774
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000753462
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [185]	valid_0's l2: 0.000555618
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [213]	valid_0's l2: 0.000293757
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  41%|████      | 18/44 [00:08<00:10,  2.50it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [227]	valid_0's l2: 0.000379036
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000217153
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 0.000604918
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000594587
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  43%|████▎     | 19/44 [00:08<00:09,  2.70it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000242555
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021209
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000222531
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000607231
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000580898
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000241196
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  45%|████▌     | 20/44 [00:09<00:10,  2.27it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021728
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000301583
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000499946
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000552852
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000505791
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  48%|████▊     | 21/44 [00:10<00:12,  1.89it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000471676
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000424438
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000978774
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000631902
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [355]	valid_0's l2: 0.000250771
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  50%|█████     | 22/44 [00:11<00:15,  1.42it/s]
# Early stopping, best iteration is:
# [402]	valid_0's l2: 0.000138334
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [294]	valid_0's l2: 0.000568049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 0.000906922
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# ...
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [328]	valid_0's l2: 0.000887581
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [285]	valid_0's l2: 0.00250611
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l2: 0.00142946
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [143]	valid_0's l2: 0.00127724
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  84%|████████▍ | 37/44 [00:16<00:01,  3.94it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [174]	valid_0's l2: 0.00141348
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000517585
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000877312
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000571693
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  86%|████████▋ | 38/44 [00:17<00:01,  3.55it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000272016
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000219816
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00013871
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000273947
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  89%|████████▊ | 39/44 [00:17<00:01,  3.59it/s]
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000212684
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.52568e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 7.55637e-05
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000421923
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000718429
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid_0's l2: 0.000461694
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  91%|█████████ | 40/44 [00:17<00:01,  2.82it/s]
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000233244
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000225534
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00117843
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00230592
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.0020834
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000896794
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  93%|█████████▎| 41/44 [00:18<00:01,  2.29it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000577585
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000194221
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000385456
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000323583
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000166169
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  95%|█████████▌| 42/44 [00:19<00:01,  1.91it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000137134
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [264]	valid_0's l2: 0.000366839
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000823982
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [417]	valid_0's l2: 0.000836509
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [94]	valid_0's l2: 0.000292324
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  98%|█████████▊| 43/44 [00:19<00:00,  1.85it/s]
# Did not meet early stopping. Best iteration is:
# [466]	valid_0's l2: 0.000221901
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000948607
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00224308
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00152605
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00097525
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting: 100%|██████████| 44/44 [00:20<00:00,  2.10it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000494532
# LGBM Index Level RMSE (Tech Sentiment Only): 374.52

# %%
# Full updated script: LGBM with only Non-Technology-labeled FinBERT sentiment

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from tqdm import tqdm

# === Load stock data ===
df = pd.read_csv("cleaned_stock_data_without_arm.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(['Company', 'Date'])

# Fix commas and convert price
df['Price Close'] = df['Price Close'].astype(str).str.replace(",", ".", regex=False)
df['Price Close'] = pd.to_numeric(df['Price Close'], errors='coerce')

# Load and prepare technology-only sentiment
sentiment_df = pd.read_csv("finbert_sentiment_final.csv")
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])
sentiment_df = sentiment_df[sentiment_df['Predicted_Label'] == 'Non-Technology']

map_df = pd.read_excel("matched company names .xlsx")
map_df.columns = ['company', 'Company']
sentiment_df = sentiment_df.merge(map_df, on='company', how='inner')
sentiment_df = sentiment_df[sentiment_df['Company'] != 'ARM.O']
sentiment_df = sentiment_df[['Company', 'date', 'finbert_sentiment_label']]
sentiment_df['date'] = sentiment_df['date'].dt.normalize()

# Aggregate and map sentiment
avg_sentiment = sentiment_df.groupby(['Company', 'date'])['finbert_sentiment_label'].mean().reset_index()
avg_sentiment = avg_sentiment.rename(columns={'date': 'Date', 'finbert_sentiment_label': 'Sentiment'})

# Merge into df
df = pd.merge(df, avg_sentiment, on=['Company', 'Date'], how='left')

# Apply conditional decay to sentiment
def apply_conditional_decay(series, decay=0.9):
    output = []
    last_val = None
    for val in series:
        if pd.notna(val):
            if val == 0:
                last_val = None
                output.append(np.nan)
            else:
                last_val = val
                output.append(val)
        else:
            if last_val is not None:
                last_val *= decay
                output.append(last_val)
            else:
                output.append(np.nan)
    return output

df = df.sort_values(['Company', 'Date'])
df['Sentiment'] = df.groupby('Company')['Sentiment'].transform(lambda x: apply_conditional_decay(x))

# Time features
df['DayOfWeek'] = df['Date'].dt.dayofweek
df['Month'] = df['Date'].dt.month
df['Day_Sin'] = np.sin(2 * np.pi * df['DayOfWeek'] / 7)
df['Day_Cos'] = np.cos(2 * np.pi * df['DayOfWeek'] / 7)
df['Month_Sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_Cos'] = np.cos(2 * np.pi * df['Month'] / 12)

# Lagged return, price, volume
df['Return'] = df.groupby('Company')['Price Close'].pct_change()
df['Lag1_Return'] = df.groupby('Company')['Return'].shift(1)
df['Lag2_Return'] = df.groupby('Company')['Return'].shift(2)
df['Lag3_Return'] = df.groupby('Company')['Return'].shift(3)
df['Lagged_Volume'] = df.groupby('Company')['Volume'].shift(1)

# Rolling stats
df['RollingStd_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).std())
df['RollingMean_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).mean())

# Lagged sentiment
df['Lagged_Sentiment'] = df.groupby('Company')['Sentiment'].shift(1)

# Drop rows with missing target only (predicting return)
df = df.dropna(subset=['Return'])

# Load best params and index
param_df = pd.read_csv("best_params_all_companies.csv")
index_df = pd.read_csv("equal_weighted_index_without_arm.csv")
index_df['Date'] = pd.to_datetime(index_df['Date'])

# Split
unique_dates = df['Date'].sort_values().unique()
split_idx = int(len(unique_dates) * 0.8)
train_dates = unique_dates[:split_idx]
test_dates = unique_dates[split_idx:]

last_train_date = train_dates[-1]
start_value = index_df.loc[index_df['Date'] == last_train_date, 'Index_Level'].values[0] \
    if last_train_date in index_df['Date'].values else index_df[index_df['Date'] < last_train_date]['Index_Level'].iloc[-1]

# === Training ===
all_preds = []
plotted = 0

for company in tqdm(df['Company'].unique(), desc="LGBM Forecasting"):
    company_data = df[df['Company'] == company].copy()
    params_row = param_df[param_df['Company'] == company]

    if len(params_row) == 0:
        continue

    params = {
        'num_leaves': int(params_row['num_leaves'].values[0]),
        'learning_rate': float(params_row['learning_rate'].values[0]),
        'feature_fraction': float(params_row['feature_fraction'].values[0]),
        'min_data_in_leaf': int(params_row['min_data_in_leaf'].values[0]),
        'lambda_l2': float(params_row['lambda_l2'].values[0]),
        'lambda_l1': 0.5,
        'max_depth': 6,
        'verbosity': -1
    }

    train = company_data[company_data['Date'].isin(train_dates)]
    test = company_data[company_data['Date'].isin(test_dates)]
    if len(train) < 50 or len(test) < 1:
        continue

    features = [
        'Lag1_Return', 'Lag2_Return', 'Lag3_Return', 'Lagged_Volume',
        'RollingStd_5', 'RollingMean_5', 'Lagged_Sentiment',
        'Day_Sin', 'Day_Cos', 'Month_Sin', 'Month_Cos'
    ]

    X_all = company_data[features].values
    y_all = company_data['Return'].values.reshape(-1, 1)

    split_idx = len(train)
    X_train = X_all[:split_idx]
    y_train = y_all[:split_idx]
    X_test = X_all[split_idx:]
    y_test = y_all[split_idx:]

    f_scaler = StandardScaler()
    X_train_scaled = f_scaler.fit_transform(X_train)
    X_test_scaled = f_scaler.transform(X_test)

    model = lgb.LGBMRegressor(n_estimators=500, **params)
    tscv = TimeSeriesSplit(n_splits=5)
    for train_idx, val_idx in tscv.split(X_train_scaled):
        model.fit(
            X_train_scaled[train_idx], y_train[train_idx].ravel(),
            eval_set=[(X_train_scaled[val_idx], y_train[val_idx].ravel())],
            callbacks=[early_stopping(50), log_evaluation(0)]
        )

    preds = model.predict(X_test_scaled)
    test_result = test.iloc[-len(preds):].copy()
    test_result['Predicted_Return'] = preds
    test_result['Predicted_Return'] = test_result['Predicted_Return'].clip(lower=-0.1, upper=0.1)

    test_result['Predicted_Price'] = test_result['Price Close'].shift(1) * (1 + test_result['Predicted_Return'])
    test_result['Predicted_Price'] = test_result['Predicted_Price'].cumprod() / test_result['Predicted_Price'].iloc[0] * test_result['Price Close'].iloc[0]

    if plotted < 5:
        plt.figure(figsize=(10, 4))
        plt.plot(test_result['Date'], test_result['Price Close'], label='Actual', color='blue')
        plt.plot(test_result['Date'], test_result['Predicted_Price'], label='Predicted', color='orange')
        plt.title(f"{company} - Predicted vs Actual Price")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.legend()
        plt.tight_layout()
        plt.savefig(f"pred_vs_actual_{company}_tech_only.png", dpi=200)
        plt.close()
        plotted += 1

    test_result['Company'] = company
    all_preds.append(test_result[['Date', 'Company', 'Predicted_Return']])

# === Aggregate index ===
combined = pd.concat(all_preds)
index_returns = combined.groupby('Date')['Predicted_Return'].mean().reset_index()
index_returns.rename(columns={'Predicted_Return': 'Index_Predicted_Return'}, inplace=True)
index_returns['Predicted_Index_Level'] = (1 + index_returns['Index_Predicted_Return']).cumprod() * start_value

index_df['Date'] = pd.to_datetime(index_df['Date'])
index_returns['Date'] = pd.to_datetime(index_returns['Date'])

final = pd.merge(index_df[['Date', 'Index_Level']], index_returns, on='Date', how='inner')
final.to_csv("lgbm_index_non-tech_sentiment_only.csv", index=False)

plt.figure(figsize=(14, 6))
plt.plot(final['Date'], final['Index_Level'], label='Actual Index Price', color='blue')
plt.plot(final['Date'], final['Predicted_Index_Level'], label='Predicted Index Price', color='orange')
plt.xlabel("Date")
plt.ylabel("Index Price")
plt.legend()
plt.tight_layout()
plt.savefig("lgbm_index_non-tech_sentiment_forecast.png", dpi=300)
plt.show()

rmse = np.sqrt(mean_squared_error(final['Index_Level'], final['Predicted_Index_Level']))
print(f"LGBM Index Level RMSE (Non-Tech Sentiment Only): {rmse:.2f}")
# Out:
# LGBM Forecasting:   0%|          | 0/44 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [343]	valid_0's l2: 0.000231288
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [474]	valid_0's l2: 0.000431824
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000426199
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [322]	valid_0's l2: 0.000109296
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.67225e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   2%|▏         | 1/44 [00:00<00:31,  1.36it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00047763
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00070493
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [207]	valid_0's l2: 0.000613577
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000342955
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000215637
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   5%|▍         | 2/44 [00:01<00:40,  1.04it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00023705
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000499116
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000433869
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000215415
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000151252
# LGBM Forecasting:   7%|▋         | 3/44 [00:02<00:39,  1.03it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000603801
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000925462
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000616345
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000367197
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [292]	valid_0's l2: 0.000201508
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   9%|▉         | 4/44 [00:03<00:32,  1.22it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00061012
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000889343
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000690199
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000308205
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000274864
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  11%|█▏        | 5/44 [00:04<00:32,  1.21it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000968449
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00141868
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l2: 0.000982033
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000573557
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  14%|█▎        | 6/44 [00:04<00:24,  1.53it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000483037
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000321374
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000683946
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [183]	valid_0's l2: 0.000455065
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  16%|█▌        | 7/44 [00:04<00:19,  1.90it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000216498
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [411]	valid_0's l2: 0.00040243
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [361]	valid_0's l2: 0.00178168
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00306192
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00177051
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [176]	valid_0's l2: 0.00107291
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [139]	valid_0's l2: 0.000893366
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  18%|█▊        | 8/44 [00:05<00:16,  2.22it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00050162
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000971433
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [371]	valid_0's l2: 0.000729912
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000244613
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  20%|██        | 9/44 [00:05<00:13,  2.56it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [194]	valid_0's l2: 0.000243622
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00030115
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [278]	valid_0's l2: 0.000492414
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [293]	valid_0's l2: 0.000414746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [240]	valid_0's l2: 0.000374923
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  23%|██▎       | 10/44 [00:05<00:11,  2.92it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [323]	valid_0's l2: 0.000324575
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000445451
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000674413
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l2: 0.000404069
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000217984
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  25%|██▌       | 11/44 [00:05<00:10,  3.10it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000207979
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000238897
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [379]	valid_0's l2: 0.000401099
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000273407
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [468]	valid_0's l2: 0.000254528
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  27%|██▋       | 12/44 [00:06<00:09,  3.41it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [495]	valid_0's l2: 8.00383e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000875304
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00185741
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [267]	valid_0's l2: 0.000882633
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  30%|██▉       | 13/44 [00:06<00:10,  3.06it/s]
# Early stopping, best iteration is:
# [303]	valid_0's l2: 0.00053419
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000397913
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000178441
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000448209
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000447048
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000202485
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  32%|███▏      | 14/44 [00:06<00:09,  3.06it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [252]	valid_0's l2: 9.82708e-05
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00133768
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00339123
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [257]	valid_0's l2: 0.00123478
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [151]	valid_0's l2: 0.000361377
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [224]	valid_0's l2: 0.000521447
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  34%|███▍      | 15/44 [00:07<00:08,  3.46it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid_0's l2: 0.00110623
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	valid_0's l2: 0.0024427
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [349]	valid_0's l2: 0.00118651
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l2: 0.000727279
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l2: 0.000734987
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  36%|███▋      | 16/44 [00:07<00:07,  3.72it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000751
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00130682
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [466]	valid_0's l2: 0.000661376
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid_0's l2: 0.000617586
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  39%|███▊      | 17/44 [00:07<00:07,  3.60it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [405]	valid_0's l2: 0.000304997
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00149774
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000758423
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [167]	valid_0's l2: 0.000558448
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [208]	valid_0's l2: 0.000297861
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  41%|████      | 18/44 [00:07<00:07,  3.67it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [243]	valid_0's l2: 0.000378351
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000217153
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 0.000604918
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000594587
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  43%|████▎     | 19/44 [00:08<00:06,  3.70it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000243384
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000211268
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000222531
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000607231
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000580898
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000238905
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  45%|████▌     | 20/44 [00:08<00:07,  3.06it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000217617
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000301583
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000499946
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000552852
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000505312
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  48%|████▊     | 21/44 [00:09<00:08,  2.71it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000472625
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000424438
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000978774
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000631902
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [355]	valid_0's l2: 0.000250771
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  50%|█████     | 22/44 [00:09<00:07,  2.95it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [402]	valid_0's l2: 0.000138334
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [294]	valid_0's l2: 0.000568049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 0.000906922
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [226]	valid_0's l2: 0.000504958
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  84%|████████▍ | 37/44 [00:15<00:01,  3.82it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [268]	valid_0's l2: 0.000867445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [370]	valid_0's l2: 0.00250435
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [127]	valid_0's l2: 0.00142654
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [174]	valid_0's l2: 0.00127312
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [135]	valid_0's l2: 0.00140392
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000517585
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000877312
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000569598
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000272674
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  86%|████████▋ | 38/44 [00:15<00:01,  3.51it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000220256
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00013871
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000273885
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000212594
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  89%|████████▊ | 39/44 [00:15<00:01,  3.70it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.52568e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 7.55637e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000421923
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000718429
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid_0's l2: 0.000461694
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  91%|█████████ | 40/44 [00:16<00:01,  2.94it/s]
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000233244
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000225534
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00117843
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00230635
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00208152
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  93%|█████████▎| 41/44 [00:16<00:01,  2.70it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000895967
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000579624
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000194221
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000385456
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000323583
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000166169
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  95%|█████████▌| 42/44 [00:17<00:00,  2.77it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000137134
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [255]	valid_0's l2: 0.000366839
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000823982
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [417]	valid_0's l2: 0.000836509
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [108]	valid_0's l2: 0.000294188
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  98%|█████████▊| 43/44 [00:17<00:00,  3.04it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000222012
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000948607
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00224308
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00151299
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000969287
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting: 100%|██████████| 44/44 [00:17<00:00,  2.45it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00049243
# LGBM Index Level RMSE (Non-Tech Sentiment Only): 383.08

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from tqdm import tqdm

# === Load stock data ===
df = pd.read_csv("cleaned_stock_data_without_arm.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(['Company', 'Date'])
df['Price Close'] = df['Price Close'].astype(str).str.replace(",", ".", regex=False)
df['Price Close'] = pd.to_numeric(df['Price Close'], errors='coerce')

# === Load and filter Roberta sentiment ===
sentiment_df = pd.read_csv("roberta_sentiment_final.csv")
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])
sentiment_df = sentiment_df[sentiment_df['Predicted_Label'] == 'Technology']

map_df = pd.read_excel("matched company names .xlsx")
map_df.columns = ['company', 'Company']
sentiment_df['company'] = sentiment_df['company'].str.strip()
map_df['company'] = map_df['company'].str.strip()
sentiment_df = sentiment_df.merge(map_df, on='company', how='inner')
sentiment_df = sentiment_df[sentiment_df['Company'] != 'ARM.O']
sentiment_df = sentiment_df[['Company', 'date', 'roberta_sentiment']]
sentiment_df['date'] = sentiment_df['date'].dt.normalize()

# Aggregate and map sentiment
avg_sentiment = sentiment_df.groupby(['Company', 'date'])['roberta_sentiment'].mean().reset_index()
avg_sentiment = avg_sentiment.rename(columns={'date': 'Date', 'roberta_sentiment': 'Sentiment'})

# Merge into df
df = pd.merge(df, avg_sentiment, on=['Company', 'Date'], how='left')

# Apply conditional decay to sentiment
def apply_conditional_decay(series, decay=0.9):
    output = []
    last_val = None
    for val in series:
        if pd.notna(val):
            if val == 0:
                last_val = None
                output.append(np.nan)
            else:
                last_val = val
                output.append(val)
        else:
            if last_val is not None:
                last_val *= decay
                output.append(last_val)
            else:
                output.append(np.nan)
    return output

df = df.sort_values(['Company', 'Date'])
df['Sentiment'] = df.groupby('Company')['Sentiment'].transform(lambda x: apply_conditional_decay(x))

# Time features
df['DayOfWeek'] = df['Date'].dt.dayofweek
df['Month'] = df['Date'].dt.month
df['Day_Sin'] = np.sin(2 * np.pi * df['DayOfWeek'] / 7)
df['Day_Cos'] = np.cos(2 * np.pi * df['DayOfWeek'] / 7)
df['Month_Sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_Cos'] = np.cos(2 * np.pi * df['Month'] / 12)

# Lagged return, price, volume
df['Return'] = df.groupby('Company')['Price Close'].pct_change()
df['Lag1_Return'] = df.groupby('Company')['Return'].shift(1)
df['Lag2_Return'] = df.groupby('Company')['Return'].shift(2)
df['Lag3_Return'] = df.groupby('Company')['Return'].shift(3)
df['Lagged_Volume'] = df.groupby('Company')['Volume'].shift(1)

# Rolling stats
df['RollingStd_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).std())
df['RollingMean_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).mean())

# Lagged sentiment
df['Lagged_Sentiment'] = df.groupby('Company')['Sentiment'].shift(1)

# Drop rows with missing target only (predicting return)
df = df.dropna(subset=['Return'])

# Load best params and index
param_df = pd.read_csv("best_params_all_companies.csv")
index_df = pd.read_csv("equal_weighted_index_without_arm.csv")
index_df['Date'] = pd.to_datetime(index_df['Date'])

# Split
unique_dates = df['Date'].sort_values().unique()
split_idx = int(len(unique_dates) * 0.8)
train_dates = unique_dates[:split_idx]
test_dates = unique_dates[split_idx:]

last_train_date = train_dates[-1]
start_value = index_df.loc[index_df['Date'] == last_train_date, 'Index_Level'].values[0] \
    if last_train_date in index_df['Date'].values else index_df[index_df['Date'] < last_train_date]['Index_Level'].iloc[-1]

# === Training ===
all_preds = []
plotted = 0

for company in tqdm(df['Company'].unique(), desc="LGBM Forecasting"):
    company_data = df[df['Company'] == company].copy()
    params_row = param_df[param_df['Company'] == company]

    if len(params_row) == 0:
        continue

    params = {
        'num_leaves': int(params_row['num_leaves'].values[0]),
        'learning_rate': float(params_row['learning_rate'].values[0]),
        'feature_fraction': float(params_row['feature_fraction'].values[0]),
        'min_data_in_leaf': int(params_row['min_data_in_leaf'].values[0]),
        'lambda_l2': float(params_row['lambda_l2'].values[0]),
        'lambda_l1': 0.5,
        'max_depth': 6,
        'verbosity': -1
    }

    train = company_data[company_data['Date'].isin(train_dates)]
    test = company_data[company_data['Date'].isin(test_dates)]
    if len(train) < 50 or len(test) < 1:
        continue

    features = [
        'Lag1_Return', 'Lag2_Return', 'Lag3_Return', 'Lagged_Volume',
        'RollingStd_5', 'RollingMean_5', 'Lagged_Sentiment',
        'Day_Sin', 'Day_Cos', 'Month_Sin', 'Month_Cos'
    ]

    X_all = company_data[features].values
    y_all = company_data['Return'].values.reshape(-1, 1)

    split_idx = len(train)
    X_train = X_all[:split_idx]
    y_train = y_all[:split_idx]
    X_test = X_all[split_idx:]
    y_test = y_all[split_idx:]

    f_scaler = StandardScaler()
    X_train_scaled = f_scaler.fit_transform(X_train)
    X_test_scaled = f_scaler.transform(X_test)

    model = lgb.LGBMRegressor(n_estimators=500, **params)
    tscv = TimeSeriesSplit(n_splits=5)
    for train_idx, val_idx in tscv.split(X_train_scaled):
        model.fit(
            X_train_scaled[train_idx], y_train[train_idx].ravel(),
            eval_set=[(X_train_scaled[val_idx], y_train[val_idx].ravel())],
            callbacks=[early_stopping(50), log_evaluation(0)]
        )

    preds = model.predict(X_test_scaled)
    test_result = test.iloc[-len(preds):].copy()
    test_result['Predicted_Return'] = preds
    test_result['Predicted_Return'] = test_result['Predicted_Return'].clip(lower=-0.1, upper=0.1)
    test_result['Predicted_Price'] = test_result['Price Close'].shift(1) * (1 + test_result['Predicted_Return'])
    test_result['Predicted_Price'] = test_result['Predicted_Price'].cumprod() / test_result['Predicted_Price'].iloc[0] * test_result['Price Close'].iloc[0]

    if plotted < 5:
        plt.figure(figsize=(10, 4))
        plt.plot(test_result['Date'], test_result['Price Close'], label='Actual', color='blue')
        plt.plot(test_result['Date'], test_result['Predicted_Price'], label='Predicted', color='orange')
        plt.title(f"{company} - Predicted vs Actual Price")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.legend()
        plt.tight_layout()
        plt.savefig(f"pred_vs_actual_{company}.png", dpi=200)
        plt.close()
        plotted += 1

    test_result['Company'] = company
    all_preds.append(test_result[['Date', 'Company', 'Predicted_Return']])

# === Aggregate index ===
combined = pd.concat(all_preds)
index_returns = combined.groupby('Date')['Predicted_Return'].mean().reset_index()
index_returns.rename(columns={'Predicted_Return': 'Index_Predicted_Return'}, inplace=True)
index_returns['Predicted_Index_Level'] = (1 + index_returns['Index_Predicted_Return']).cumprod() * start_value

final = pd.merge(index_df[['Date', 'Index_Level']], index_returns, on='Date', how='inner')
final.to_csv("lgbm_roberta_tech_index.csv", index=False)

plt.figure(figsize=(14, 6))
plt.plot(final['Date'], final['Index_Level'], label='Actual Index Price', color='blue')
plt.plot(final['Date'], final['Predicted_Index_Level'], label='Predicted Index Price', color='orange')
plt.xlabel("Date")
plt.ylabel("Index Price")
plt.legend()
plt.tight_layout()
plt.savefig("lgbm_roberta_tech_index_forecast.png", dpi=300)
plt.show()

rmse = np.sqrt(mean_squared_error(final['Index_Level'], final['Predicted_Index_Level']))
print(f"LGBM Index Level RMSE (Roberta Technology): {rmse:.2f}")
# Out:
# LGBM Forecasting:   0%|          | 0/44 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [343]	valid_0's l2: 0.000231288
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [474]	valid_0's l2: 0.000431824
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000426199
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [322]	valid_0's l2: 0.000109296
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.67225e-05
# LGBM Forecasting:   2%|▏         | 1/44 [00:01<00:49,  1.15s/it]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00047763
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00070493
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [207]	valid_0's l2: 0.000613577
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000342955
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021543
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   5%|▍         | 2/44 [00:02<00:43,  1.03s/it]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00023705
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000499116
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000434658
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000215415
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000151252
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   7%|▋         | 3/44 [00:03<00:40,  1.02it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000603801
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000925462
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000616345
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000367197
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [292]	valid_0's l2: 0.000201508
# LGBM Forecasting:   9%|▉         | 4/44 [00:03<00:32,  1.24it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00061012
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000889343
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000690199
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000306811
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00027415
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  11%|█▏        | 5/44 [00:04<00:31,  1.25it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000968449
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00141852
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l2: 0.000982033
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000573557
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  14%|█▎        | 6/44 [00:04<00:23,  1.61it/s]
# Early stopping, best iteration is:
# [368]	valid_0's l2: 0.000491701
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000321374
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000683946
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [183]	valid_0's l2: 0.000455065
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000219674
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  16%|█▌        | 7/44 [00:04<00:18,  2.00it/s]
# Early stopping, best iteration is:
# [391]	valid_0's l2: 0.000401477
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [361]	valid_0's l2: 0.00178168
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00307543
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00171141
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  18%|█▊        | 8/44 [00:05<00:16,  2.17it/s]
# Early stopping, best iteration is:
# [197]	valid_0's l2: 0.00107466
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [205]	valid_0's l2: 0.000883635
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00050162
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000971431
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [192]	valid_0's l2: 0.000732125
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  20%|██        | 9/44 [00:05<00:15,  2.25it/s]
# Early stopping, best iteration is:
# [201]	valid_0's l2: 0.00024484
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [467]	valid_0's l2: 0.000246402
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00030115
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [278]	valid_0's l2: 0.000492414
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [293]	valid_0's l2: 0.000414746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [240]	valid_0's l2: 0.000374923
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  23%|██▎       | 10/44 [00:06<00:14,  2.27it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [323]	valid_0's l2: 0.000324575
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000445451
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000674433
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l2: 0.000404069
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000217984
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  25%|██▌       | 11/44 [00:06<00:14,  2.21it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000207979
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000238897
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [379]	valid_0's l2: 0.000401099
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000273407
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [468]	valid_0's l2: 0.000254528
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  27%|██▋       | 12/44 [00:06<00:13,  2.30it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 7.93846e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000875304
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00185741
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000902806
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [331]	valid_0's l2: 0.000518304
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  30%|██▉       | 13/44 [00:07<00:16,  1.93it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000393214
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000178441
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000448209
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000447048
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000202485
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  32%|███▏      | 14/44 [00:08<00:15,  1.92it/s]
# Early stopping, best iteration is:
# [252]	valid_0's l2: 9.82708e-05
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00133768
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00338817
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [226]	valid_0's l2: 0.00121513
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  34%|███▍      | 15/44 [00:08<00:13,  2.19it/s]
# Early stopping, best iteration is:
# [125]	valid_0's l2: 0.0003663
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [195]	valid_0's l2: 0.000528086
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid_0's l2: 0.00110623
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	valid_0's l2: 0.0024427
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  36%|███▋      | 16/44 [00:08<00:10,  2.58it/s]
# Early stopping, best iteration is:
# [354]	valid_0's l2: 0.001187
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	valid_0's l2: 0.000728956
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l2: 0.000762422
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000751
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00130682
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  39%|███▊      | 17/44 [00:09<00:09,  2.85it/s]
# Did not meet early stopping. Best iteration is:
# [466]	valid_0's l2: 0.000661376
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid_0's l2: 0.000617586
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [431]	valid_0's l2: 0.00030397
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.00149751
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000758423
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [167]	valid_0's l2: 0.000558448
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [208]	valid_0's l2: 0.000297861
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [243]	valid_0's l2: 0.000378351
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  41%|████      | 18/44 [00:09<00:08,  3.11it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000217153
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 0.000604918
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000594587
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000241738
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  43%|████▎     | 19/44 [00:09<00:07,  3.34it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021209
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000222531
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000607231
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000580898
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  45%|████▌     | 20/44 [00:09<00:07,  3.14it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000241457
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021728
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000301583
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000499946
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000552852
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  48%|████▊     | 21/44 [00:10<00:08,  2.82it/s]
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000505312
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000472783
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000424438
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000978774
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  50%|█████     | 22/44 [00:10<00:07,  3.07it/s]
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000632304
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [355]	valid_0's l2: 0.000250771
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [402]	valid_0's l2: 0.000138334
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  52%|█████▏    | 23/44 [00:10<00:05,  3.53it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 0.000568049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [436]	valid_0's l2: 0.000906677
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l2: 0.000498326
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [99]	valid_0's l2: 0.000343521
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [210]	valid_0's l2: 0.000240774
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  84%|████████▍ | 37/44 [00:15<00:02,  3.27it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [268]	valid_0's l2: 0.000867445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [370]	valid_0's l2: 0.00250435
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l2: 0.00142946
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [147]	valid_0's l2: 0.00127775
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [158]	valid_0's l2: 0.00139683
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000517585
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000877312
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000570781
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000273816
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  86%|████████▋ | 38/44 [00:16<00:01,  3.19it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000219009
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00013871
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000273947
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  89%|████████▊ | 39/44 [00:16<00:01,  3.37it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000212684
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.53279e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 7.56834e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000421923
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000718429
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid_0's l2: 0.000461694
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  91%|█████████ | 40/44 [00:17<00:01,  2.89it/s]
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000233244
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000225534
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00117852
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00230598
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00207926
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  93%|█████████▎| 41/44 [00:17<00:01,  2.69it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000895967
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000580681
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000194221
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000385456
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000323583
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000166169
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  95%|█████████▌| 42/44 [00:17<00:00,  2.85it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000137134
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [264]	valid_0's l2: 0.000366839
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000823982
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [398]	valid_0's l2: 0.000836668
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [136]	valid_0's l2: 0.00029275
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  98%|█████████▊| 43/44 [00:18<00:00,  3.15it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000222682
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000948607
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00224308
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00151299
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000965617
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting: 100%|██████████| 44/44 [00:18<00:00,  2.37it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000490047
# LGBM Index Level RMSE (Roberta Technology): 371.91

# %%
#roberta non-tech
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from tqdm import tqdm

# === Load stock data ===
df = pd.read_csv("cleaned_stock_data_without_arm.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(['Company', 'Date'])
df['Price Close'] = df['Price Close'].astype(str).str.replace(",", ".", regex=False)
df['Price Close'] = pd.to_numeric(df['Price Close'], errors='coerce')

# === Load and filter Roberta sentiment ===
sentiment_df = pd.read_csv("roberta_sentiment_final.csv")
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])
sentiment_df = sentiment_df[sentiment_df['Predicted_Label'] == 'Non-Technology']

map_df = pd.read_excel("matched company names .xlsx")
map_df.columns = ['company', 'Company']
sentiment_df['company'] = sentiment_df['company'].str.strip()
map_df['company'] = map_df['company'].str.strip()
sentiment_df = sentiment_df.merge(map_df, on='company', how='inner')
sentiment_df = sentiment_df[sentiment_df['Company'] != 'ARM.O']
sentiment_df = sentiment_df[['Company', 'date', 'roberta_sentiment']]
sentiment_df['date'] = sentiment_df['date'].dt.normalize()

# Aggregate and map sentiment
avg_sentiment = sentiment_df.groupby(['Company', 'date'])['roberta_sentiment'].mean().reset_index()
avg_sentiment = avg_sentiment.rename(columns={'date': 'Date', 'roberta_sentiment': 'Sentiment'})

# Merge into df
df = pd.merge(df, avg_sentiment, on=['Company', 'Date'], how='left')

# Apply conditional decay to sentiment
def apply_conditional_decay(series, decay=0.9):
    output = []
    last_val = None
    for val in series:
        if pd.notna(val):
            if val == 0:
                last_val = None
                output.append(np.nan)
            else:
                last_val = val
                output.append(val)
        else:
            if last_val is not None:
                last_val *= decay
                output.append(last_val)
            else:
                output.append(np.nan)
    return output

df = df.sort_values(['Company', 'Date'])
df['Sentiment'] = df.groupby('Company')['Sentiment'].transform(lambda x: apply_conditional_decay(x))

# Time features
df['DayOfWeek'] = df['Date'].dt.dayofweek
df['Month'] = df['Date'].dt.month
df['Day_Sin'] = np.sin(2 * np.pi * df['DayOfWeek'] / 7)
df['Day_Cos'] = np.cos(2 * np.pi * df['DayOfWeek'] / 7)
df['Month_Sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_Cos'] = np.cos(2 * np.pi * df['Month'] / 12)

# Lagged return, price, volume
df['Return'] = df.groupby('Company')['Price Close'].pct_change()
df['Lag1_Return'] = df.groupby('Company')['Return'].shift(1)
df['Lag2_Return'] = df.groupby('Company')['Return'].shift(2)
df['Lag3_Return'] = df.groupby('Company')['Return'].shift(3)
df['Lagged_Volume'] = df.groupby('Company')['Volume'].shift(1)

# Rolling stats
df['RollingStd_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).std())
df['RollingMean_5'] = df.groupby('Company')['Return'].transform(lambda x: x.rolling(5).mean())

# Lagged sentiment
df['Lagged_Sentiment'] = df.groupby('Company')['Sentiment'].shift(1)

# Drop rows with missing target only (predicting return)
df = df.dropna(subset=['Return'])

# Load best params and index
param_df = pd.read_csv("best_params_all_companies.csv")
index_df = pd.read_csv("equal_weighted_index_without_arm.csv")
index_df['Date'] = pd.to_datetime(index_df['Date'])

# Split
unique_dates = df['Date'].sort_values().unique()
split_idx = int(len(unique_dates) * 0.8)
train_dates = unique_dates[:split_idx]
test_dates = unique_dates[split_idx:]

last_train_date = train_dates[-1]
start_value = index_df.loc[index_df['Date'] == last_train_date, 'Index_Level'].values[0] \
    if last_train_date in index_df['Date'].values else index_df[index_df['Date'] < last_train_date]['Index_Level'].iloc[-1]

# === Training ===
all_preds = []
plotted = 0

for company in tqdm(df['Company'].unique(), desc="LGBM Forecasting"):
    company_data = df[df['Company'] == company].copy()
    params_row = param_df[param_df['Company'] == company]

    if len(params_row) == 0:
        continue

    params = {
        'num_leaves': int(params_row['num_leaves'].values[0]),
        'learning_rate': float(params_row['learning_rate'].values[0]),
        'feature_fraction': float(params_row['feature_fraction'].values[0]),
        'min_data_in_leaf': int(params_row['min_data_in_leaf'].values[0]),
        'lambda_l2': float(params_row['lambda_l2'].values[0]),
        'lambda_l1': 0.5,
        'max_depth': 6,
        'verbosity': -1
    }

    train = company_data[company_data['Date'].isin(train_dates)]
    test = company_data[company_data['Date'].isin(test_dates)]
    if len(train) < 50 or len(test) < 1:
        continue

    features = [
        'Lag1_Return', 'Lag2_Return', 'Lag3_Return', 'Lagged_Volume',
        'RollingStd_5', 'RollingMean_5', 'Lagged_Sentiment',
        'Day_Sin', 'Day_Cos', 'Month_Sin', 'Month_Cos'
    ]

    X_all = company_data[features].values
    y_all = company_data['Return'].values.reshape(-1, 1)

    split_idx = len(train)
    X_train = X_all[:split_idx]
    y_train = y_all[:split_idx]
    X_test = X_all[split_idx:]
    y_test = y_all[split_idx:]

    f_scaler = StandardScaler()
    X_train_scaled = f_scaler.fit_transform(X_train)
    X_test_scaled = f_scaler.transform(X_test)

    model = lgb.LGBMRegressor(n_estimators=500, **params)
    tscv = TimeSeriesSplit(n_splits=5)
    for train_idx, val_idx in tscv.split(X_train_scaled):
        model.fit(
            X_train_scaled[train_idx], y_train[train_idx].ravel(),
            eval_set=[(X_train_scaled[val_idx], y_train[val_idx].ravel())],
            callbacks=[early_stopping(50), log_evaluation(0)]
        )

    preds = model.predict(X_test_scaled)
    test_result = test.iloc[-len(preds):].copy()
    test_result['Predicted_Return'] = preds
    test_result['Predicted_Return'] = test_result['Predicted_Return'].clip(lower=-0.1, upper=0.1)
    test_result['Predicted_Price'] = test_result['Price Close'].shift(1) * (1 + test_result['Predicted_Return'])
    test_result['Predicted_Price'] = test_result['Predicted_Price'].cumprod() / test_result['Predicted_Price'].iloc[0] * test_result['Price Close'].iloc[0]

    if plotted < 5:
        plt.figure(figsize=(10, 4))
        plt.plot(test_result['Date'], test_result['Price Close'], label='Actual', color='blue')
        plt.plot(test_result['Date'], test_result['Predicted_Price'], label='Predicted', color='orange')
        plt.title(f"{company} - Predicted vs Actual Price")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.legend()
        plt.tight_layout()
        plt.savefig(f"pred_vs_actual_{company}.png", dpi=200)
        plt.close()
        plotted += 1

    test_result['Company'] = company
    all_preds.append(test_result[['Date', 'Company', 'Predicted_Return']])

# === Aggregate index ===
combined = pd.concat(all_preds)
index_returns = combined.groupby('Date')['Predicted_Return'].mean().reset_index()
index_returns.rename(columns={'Predicted_Return': 'Index_Predicted_Return'}, inplace=True)
index_returns['Predicted_Index_Level'] = (1 + index_returns['Index_Predicted_Return']).cumprod() * start_value

final = pd.merge(index_df[['Date', 'Index_Level']], index_returns, on='Date', how='inner')
final.to_csv("lgbm_roberta_non-tech_index.csv", index=False)

plt.figure(figsize=(14, 6))
plt.plot(final['Date'], final['Index_Level'], label='Actual Index Price', color='blue')
plt.plot(final['Date'], final['Predicted_Index_Level'], label='Predicted Index Price', color='orange')
plt.xlabel("Date")
plt.ylabel("Index Price")
plt.legend()
plt.tight_layout()
plt.savefig("lgbm_roberta_non-tech_index_forecast.png", dpi=300)
plt.show()

rmse = np.sqrt(mean_squared_error(final['Index_Level'], final['Predicted_Index_Level']))
print(f"LGBM Index Level RMSE (Roberta Non-Technology): {rmse:.2f}")
# Out:
# LGBM Forecasting:   0%|          | 0/44 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [343]	valid_0's l2: 0.000231288
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [474]	valid_0's l2: 0.000431824
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000426199
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [322]	valid_0's l2: 0.000109296
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.67225e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   2%|▏         | 1/44 [00:00<00:27,  1.58it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00047763
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00070493
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [207]	valid_0's l2: 0.000613577
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000342955
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021543
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:   5%|▍         | 2/44 [00:01<00:26,  1.60it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00023705
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000499116
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000433869
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000215415
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000151252
# LGBM Forecasting:   7%|▋         | 3/44 [00:01<00:26,  1.58it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000603801
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000925462
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000614861
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000367677
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [292]	valid_0's l2: 0.000201508
# LGBM Forecasting:   9%|▉         | 4/44 [00:02<00:24,  1.64it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00061012
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000889343
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000690199
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000307411
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000274508
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  11%|█▏        | 5/44 [00:03<00:26,  1.50it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000968449
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00141852
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [234]	valid_0's l2: 0.000981828
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00057322
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  14%|█▎        | 6/44 [00:03<00:20,  1.86it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000483037
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000321374
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000683946
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [183]	valid_0's l2: 0.000455065
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000219674
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  16%|█▌        | 7/44 [00:03<00:16,  2.22it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [391]	valid_0's l2: 0.000401477
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [361]	valid_0's l2: 0.00178168
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00307543
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  18%|█▊        | 8/44 [00:04<00:14,  2.54it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00175779
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [218]	valid_0's l2: 0.00107044
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [121]	valid_0's l2: 0.000890727
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00050162
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000971433
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  20%|██        | 9/44 [00:04<00:11,  2.93it/s]
# Early stopping, best iteration is:
# [371]	valid_0's l2: 0.000729912
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [205]	valid_0's l2: 0.000246577
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [467]	valid_0's l2: 0.000246402
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00030115
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [278]	valid_0's l2: 0.000492414
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  23%|██▎       | 10/44 [00:04<00:10,  3.25it/s]
# Early stopping, best iteration is:
# [293]	valid_0's l2: 0.000414746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [240]	valid_0's l2: 0.000374923
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [323]	valid_0's l2: 0.000324575
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000445451
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000674413
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l2: 0.000404069
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000217984
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000207979
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  25%|██▌       | 11/44 [00:04<00:09,  3.33it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  27%|██▋       | 12/44 [00:05<00:08,  3.66it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000238897
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [379]	valid_0's l2: 0.000401099
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000273407
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [468]	valid_0's l2: 0.000254528
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid_0's l2: 8.00383e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000875304
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00185741
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [262]	valid_0's l2: 0.000890239
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  30%|██▉       | 13/44 [00:05<00:09,  3.35it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [288]	valid_0's l2: 0.000531836
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid_0's l2: 0.000395204
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000178441
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000448209
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  32%|███▏      | 14/44 [00:05<00:09,  3.28it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000447048
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000202485
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [252]	valid_0's l2: 9.82708e-05
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00133768
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  34%|███▍      | 15/44 [00:05<00:08,  3.62it/s]
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00338817
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [226]	valid_0's l2: 0.00121513
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [125]	valid_0's l2: 0.0003663
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [374]	valid_0's l2: 0.000526704
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  36%|███▋      | 16/44 [00:06<00:07,  3.89it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid_0's l2: 0.00110623
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	valid_0's l2: 0.0024427
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [349]	valid_0's l2: 0.00118651
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l2: 0.000727279
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l2: 0.000734987
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000751
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.00130682
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000658922
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid_0's l2: 0.000617586
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  39%|███▊      | 17/44 [00:06<00:07,  3.85it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000305582
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.00149751
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000747233
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [167]	valid_0's l2: 0.000558448
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [208]	valid_0's l2: 0.000297861
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  41%|████      | 18/44 [00:06<00:06,  3.85it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [243]	valid_0's l2: 0.000378351
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000217153
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 0.000604918
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000594587
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  43%|████▎     | 19/44 [00:06<00:06,  3.83it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000242555
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021209
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000222531
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000607231
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000580898
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000241196
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  45%|████▌     | 20/44 [00:07<00:07,  3.36it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00021728
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000301534
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000499946
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000552852
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000505312
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  48%|████▊     | 21/44 [00:07<00:08,  2.56it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000473102
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000424438
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000978774
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000631902
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [355]	valid_0's l2: 0.000250771
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  50%|█████     | 22/44 [00:08<00:08,  2.52it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [402]	valid_0's l2: 0.000138334
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [294]	valid_0's l2: 0.000568049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [436]	valid_0's l2: 0.000906677
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l2: 0.000498326
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  52%|█████▏    | 23/44 [00:08<00:07,  2.70it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [99]	valid_0's l2: 0.000343521
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [210]	valid_0's l2: 0.000240774
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [407]	valid_0's l2: 0.00052273
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...
# Early stopping, best iteration is:
# [87]	valid_0's l2: 0.000503481
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [268]	valid_0's l2: 0.000867445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [370]	valid_0's l2: 0.00250435
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l2: 0.00142946
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBM Forecasting:  84%|████████▍ | 37/44 [00:13<00:01,  4.03it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Early stopping, best iteration is:
# [420]	valid_0's l2: 0.00127277
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [160]	valid_0's l2: 0.00139767
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000517585
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000877312
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  86%|████████▋ | 38/44 [00:13<00:01,  3.66it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000568847
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.0002728
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000220079
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.00013871
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000273947
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000212684
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 8.53279e-05
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  89%|████████▊ | 39/44 [00:14<00:01,  3.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 7.56834e-05
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000421923
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000718429
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid_0's l2: 0.000461694
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  91%|█████████ | 40/44 [00:14<00:01,  3.09it/s]
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000233244
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000225534
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00117852
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.00230598
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00207867
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  93%|█████████▎| 41/44 [00:14<00:01,  2.84it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000895967
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000580255
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l2: 0.000194221
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000385456
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000323583
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l2: 0.000166169
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  95%|█████████▌| 42/44 [00:15<00:00,  2.94it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000137134
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [255]	valid_0's l2: 0.000366839
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000823982
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [417]	valid_0's l2: 0.000836509
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [108]	valid_0's l2: 0.000294188
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting:  98%|█████████▊| 43/44 [00:15<00:00,  3.24it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000222012
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid_0's l2: 0.000948607
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00224308
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00151637
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.00097651
# Training until validation scores don't improve for 50 rounds
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# LGBM Forecasting: 100%|██████████| 44/44 [00:16<00:00,  2.75it/s]
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's l2: 0.000491073
# LGBM Index Level RMSE (Roberta Non-Technology): 371.99
